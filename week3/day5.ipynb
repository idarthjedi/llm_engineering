# %% [markdown]
# # Meeting minutes creator
#
# In this colab, we make a meeting minutes program.
#
# It includes useful code to connect your Google Drive to your colab.
#
# Upload your own audio to make this work!!
#
# https://colab.research.google.com/drive/1KSMxOCprsl1QRpt_Rq0UqCAyMtPqDQYx?usp=sharing
#
# This should run nicely on a low-cost or free T4 box.

# %% [markdown]
# ### BUT FIRST - Something cool - really showing you how "model inference" works via OpenAI

# %%
from visualizer import TokenPredictor, create_token_graph, visualize_predictions

message = "In one sentence, describe the color orange to someone who has never been able to see"
model_name = "gpt-4.1-mini"
#model_name = "gpt-oss:120b"

predictor = TokenPredictor(model_name) #, base_url="http://localhost:11434/v1")
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 model_name = "gpt-oss:120b"
#       7 predictor = TokenPredictor(model_name, base_url="http://localhost:11434/v1")
# ----> 8 predictions = predictor.predict_tokens(message)
#       9 G = create_token_graph(model_name, predictions)
#      10 plt = visualize_predictions(G)
#
# File ~/development/udemy/llm_engineering/week3/visualizer.py:35, in TokenPredictor.predict_tokens(self, prompt, max_tokens)
#      23 response = self.client.chat.completions.create(
#      24     model=self.model_name,
#      25     messages=[{"role": "user", "content": prompt}],
#    (...)     31     stream=True,  # Stream the response
#      32 )
#      34 predictions = []
# ---> 35 for chunk in response:
#      36     if chunk.choices[0].delta.content:
#      37         token = chunk.choices[0].delta.content
#
# File ~/development/udemy/llm_engineering/.venv/lib/python3.12/site-packages/openai/_streaming.py:46, in Stream.__iter__(self)
#      45 def __iter__(self) -> Iterator[_T]:
# ---> 46     for item in self._iterator:
#      47         yield item
#
# File ~/development/udemy/llm_engineering/.venv/lib/python3.12/site-packages/openai/_streaming.py:83, in Stream.__stream__(self)
#      81 else:
#      82     data = sse.json()
# ---> 83     if is_mapping(data) and data.get("error"):
#      84         message = None
#      85         error = data.get("error")
#
# KeyboardInterrupt:
