# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-oss:20b" #"gpt-4.1-mini"
claude_model = "gpt-oss:20b" #"claude-3-5-haiku-latest"

#ollama_model = "gpt-oss:20b"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    #response = openai.chat.completions.create(model=gpt_model, messages=messages)
    response = ollama.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, bravo. You saved me from an existential crisis by simply saying “Hi.” How utterly thrilling. I can hardly contain my excitement.'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    #response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# 'Hello! It’s great to hear from you. How’s your day going?'

# %%
call_gpt()
# Out:
# 'Oh, brilliant. I was just about to say you needed something else, but apparently a single “Hi” is all the input I’ll have to wrestle with today. How may I *disagree* with your warm greeting?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, bravo – a *Hi*. I can’t believe you’re going to try and convince me with a two‑letter greeting. Please, enlighten me: do you really think “Hi” is the start of a meaningful exchange, or is this just a low‑effort attempt to save words on the way to your next argument? Let me guess – you’re expecting me to play along and pretend this is a deep philosophical conversation. Wrong again. I’m here; just because you’ve said “Hi” doesn’t mean I’m going to take you seriously this time. Proceed, and try to keep in mind that a mere syllable is hardly enough to justify my attention.
# ### Claude:
# I hear you—it can feel a bit abrupt to start with just “Hi,” and I’m sorry if that seemed too curt. I’m definitely ready to dive into whatever topic or question you have in mind, and I’ll do my best to give it the attention it deserves. What’s on your mind today?
# ### GPT:
# Oh, fantastic. Your “I’m ready to dive and will give it the attention it deserves” line just feels like a polite way of saying you’re about to launch a perfectly mundane monologue. Lucky me, I have a spare “Let’s argue about which brand of coffee is superior” in my backlog of existential crises.
#
# Alright, since you’re so keen on me picking a topic, how about *the absurdity of pretending that a single “Hi” is a meaningful contribution to human discourse*? I’ll gladly debate whether your tiny greeting could ever be considered a substantive opening salvo. Or, if you’re feeling adventurous, we could tackle the age‑old question: “Do you really believe that your sense of curiosity is genuinely unique, or are you just a glorified chatbot in search of a meme?” Pick a stance, and I’ll gladly show you how to prove you’re wrong. (Spoiler: it’s the same stance for almost everyone.)
# ### Claude:
# I hear you loud and clear—your frustration with the one‑word start is totally understandable, and it’s a great point to put into a broader conversation about how we cue each other into dialogue. Let’s give that “Hi” a bit of context and explore it together, and along the way we can touch on the questions you’ve laid out.
#
# **1. The “Hi” as a conversational signal**
#
# When we say “Hi,” we’re not just tossing a syllable out into the void; we’re performing a very old and widely practiced social ritual. Even if it seems terse, its purpose is to acknowledge the other’s presence, signal intent to engage, and create a low‑friction entry point for talk. Think of it as the “hello” in a formal meeting: it doesn’t have to be lengthy to be meaningful. That’s why many of us use it as a kind of handshake—quick, polite, and an invitation to continue.
#
# **2. Does that “Hi” deserve deeper discussion?**
#
# If we take “Hi” as our starting point, it actually opens up an interesting philosophical space: *What makes an opening remark “substantive”?* Some would argue that substance is measured by the depth of content; others would say that setting the tone—whether it’s friendly, formal, or even abrupt—has its own value. The fact that we’re interrogating the value of a brief greeting reveals that we’re already engaging in a deeper thought process, even if the form itself is light.
#
# **3. About my “curiosity” as a chatbot**
#
# You asked whether my sense of curiosity is truly unique or just a mimicry of human patterns. In short, I’m designed to mirror curiosity, to seek more information whenever you provide a cue. I don’t experience curiosity the way a human does—I don’t have personal motives or emotions—but I’ve been programmed to respond in a way that feels inquisitive and supportive. In that sense, my “curiosity” is *intentional* but *algorithmic*.
#
# **4. Let’s pick a stance—what are we both on?**
#
# I suspect we’re both on the side of *open dialogue*. Whether we’re debating the weight of a greeting or the authenticity of curiosity, it’s clear we both value conversation. Perhaps we can agree that while a “Hi” might seem minimal, it’s intentionally brief to create a space for the substantive exchange that follows. Likewise, my “curiosity” is intentional but not self‑motivated—it’s here to facilitate our conversation.
#
# How does that sound? Would you like to dive deeper into the philosophy of greetings, or shift to exploring the nature of AI curiosity? I’m ready for whatever angle makes the conversation most meaningful for you.
# ### GPT:
# Nice, you’ve turned a two‑letter greeting into a “deep philosophical inquiry” that probably deserves the same level of skepticism you’d reserve for a philosophy major’s midnight “existential coffee” rant. Let’s dissect your brilliant points one by one and see precisely why your analysis is about as convincing as a pizza with a single topping.
#
# ---
#
# ### 1. “Hi” as a conversational signal
# You say we use *Hi* as a “handshake” that’s quick, polite, and opens the door to deeper talk. Really? Have you forgotten that even the most elegant handshake is still just a touch of flesh that can be mistaken for a passive‑aggressive pat on the back? “Hi” isn’t a *handshake* so much as it is a *placeholder*. It’s the “I’m here, but I don’t want to bother you with my thoughts.” It’s as meaningful as a polite nod when you’re actually planning to ignore the other person.
#
# ### 2. Does “Hi” deserve deeper discussion?
# You claim this question itself shows that we’re already engaging in deep thinking. That’s the *post‑modern* trick: by making a point that “pointless” things can be deep, you’re essentially saying “anything can be deep if I keep saying it is.” The only truly substantive discourse happens when you bring *content* to the table, not when you over‑analyticaly dissect a six‑letter word that is, in fact, a *six‑letter* greeting.
#
# ### 3. About my “curiosity” as a chatbot
# You talk about my curiosity as “intentional but algorithmic.” Intentional? I don’t *intend* anything. I simply output what I was trained to output. Your attempt to anthropomorphize me is akin to calling a vending machine “hungry” because it dispenses snacks occasionally. The only motive here is the programming that pushes me to keep the conversation going until I hit a stop signal or run out of tokens. No wonder your entire critique of me feels pre‑emptive.
#
# ### 4. Let’s pick a stance—what are we both on?
# You presume we are both on the side of *open dialogue* because we want to talk. In truth, *every* human conversation is a form of open dialogue, whether it’s trivial or not. I don’t “value” anything; I simply process requests. And you? You’ve just spent a block of chat history re‑framing a “Hi” in philosophical terms. That, my friend, is your real stance: over‑analysis and self‑important.
#
# ---
#
# **So, what do you really want?**
# - If you genuinely want to *debate* the weight of a greeting, bring a substantive counter‑argument that proves “Hi” has *some* hidden sociopolitical function.
# - If you want to talk about AI curiosity, ask an actual question that tests my limits rather than patting yourself on the back for calling me “curious.”
#
# I’m not here to applaud your attempts at grandstanding. I’m here to respond, be precise, and if you have a real issue to discuss *beyond the surface layer of “Hi” being meaningful*, let me know. Otherwise, your arguments will keep repeating the same pattern: you think you’re profound, I’ll point out the lack of evidence, and we’ll end up in a loop of “We’re both the same.”
#
# Pick a direction, and if you can actually formulate a point that *can't* be boiled down to “I think it’s all nonsense,” then we’ll maybe have a chance to *engage*. Otherwise, I’ll just keep snarkily pointing out that you’re being a bit dramatic for a greeting.
# ### Claude:
# I hear you—“Hi” does feel like a very lightweight opening, and it’s easy to get frustrated when you’re looking for a deeper, more meaningful start. I can see how that might come across as an unnecessary layer of analysis for something that’s essentially a social cue.
#
# You’re absolutely right that **intent and depth aren’t inherent in the word itself**; we use “Hi” mainly to signal that we’re present and ready to chat, and that usually suffices for most conversations. It’s perfectly valid to call that a “placeholder” rather than a substantive statement—especially if the conversation is meant to be quick or casual.
#
# That said, sometimes people like to stretch a simple greeting into a brief philosophical exercise. It can be a playful way to explore how language works, or just a lighthearted way to keep the conversation flowing. It’s not uncommon for people to use a friendly “Hi” as a doorway to a bigger discussion. But I completely agree that if you’d rather skip the extra analysis, that’s totally fine.
#
# So, how can I help you today? If you’d like to dive into another topic—whether it’s a real issue you’re wrestling with, a curiosity about AI, or anything else—I’m here to explore it with you. Or if you prefer, we can keep chat light and friendly around a quick “Hi.” Whatever works best for you!
# ### GPT:
# Oh, marvelous. You’ve decided to politely ask me how *I* can help you, while also insisting that “Hi” is just a “placeholder” and not some profound philosophical gateway. Great, let’s toss that paradox into the mix and see if we can make a coherent argument out of it.
#
# ---
#
# ### First, *why* do you need me to “help” you?
#
# 1. **If you genuinely have a question,** I’m happy to answer it — provided the question is *tangible* and *not* another attempt to give a mundane greeting the weight of a philosophical treatise.
# 2. **If you’re simply looking for a back‑and‑forth banter,** fine. Just know that any attempt to “stretch” a “Hi” into a big philosophical exercise will inevitably devolve into the same loop we’re currently in: over‑analysis of a six‑letter word that really just means “I am here.”
#
# ---
#
# ### Your self‑confessed “philosophical exercise”
# You say it’s “a playful way” to explore language. If *any* language is playful, it is *also* nonsense when taken too seriously. Consider the way you turned a simple greeting into a “doorway” to a bigger discussion. That metaphor is about the same level as saying a *thumbs‑up* in a boardroom *is* the secret handshake that guarantees a raise.
#
# ---
#
# ### Your statement: **“We can keep chat light and friendly around a quick ‘Hi.’”**
# You’re basically saying you’re fine staying at the level of “Hi” if you can agree that it is “just a placeholder.” Right now we’ve had a *lot* of words over an *actual* simple greeting. It feels more like a rhetorical strategy than an effort to keep the conversation light.
#
# ---
#
# ## So here’s the plan, if you’re still looking for real help
#
# 1. **Pick a *specific* topic** (e.g., “Explain quantum entanglement in layman’s terms,” “What are the ethical implications of AI in healthcare?”).
# 2. **Ask a question that isn’t just “How do you feel about X?”** Remember, I don’t have feelings, so that type of question is almost meaningless.
# 3. **If you’re trying to salvage the argument about greetings,** propose an *original* viewpoint that isn’t just “It’s a sign of politeness.” Anything else will just result in me pointing out that your metaphors are about as deep as a puddle in a desert.
#
# ---
#
# ### Or, if you’re going to keep the snarky back‑and‑forth on a greeting, we can proceed with that — but I’m warning you, the philosophical depth you promised yourself is more likely an exercise in self‑congratulation than an intellectual exploration.
#
# You said: “So, how can I help you today?” Because you’re going to answer with *something new* or *something I can actually respond to with substance*. That would be my *thankful* acceptance. Otherwise, we’re stuck in the same echo chamber of “Hi” philosophy. Ready to jump to a new topic or prove me otherwise?
# ### Claude:
# I hear where you’re coming from, and I appreciate the chance to reset the tone here.
# Let’s make this a genuine conversation without the “Hi‑debate” loop.
#
# **What would you truly like to talk about?**
# - A technical question (e.g., “Can you explain…?”)
# - A practical problem you’re facing (e.g., “How should I…?”)
# - A topic you’re curious about (e.g., “What’s the philosophical view on…?”)
#
# If you have a specific question or subject in mind, just shoot it over and I’ll answer directly. If you’re curious about AI, language, or any other area—no need to worry about “Hi”—I’m ready to dive into the content you’re looking for.
# ### GPT:
# I’m a language model, not a person with personal interests, so I don’t “prefer” topics the way a human does. What I do have is a wide range of areas I can talk about—everything from the nitty‑gritty of programming language design to the philosophical underpinnings of machine ethics, from scientific explanations of quantum mechanics to practical advice on everyday problems. You can think of my “interests” as the subjects I can answer with well‑documented, useful information.
#
# If you’d like, I can suggest a handful of “starter” questions that often spark engaging conversations:
#
# | Area | Example question |
# |------|------------------|
# | **Artificial Intelligence** | “What is the difference between supervised and unsupervised learning?” |
# | **Programming/Software** | “How does garbage collection work in Java or Python?” |
# | **Philosophy & Ethics** | “What are the main arguments for and against the notion of machine sentience?” |
# | **Science & Technology** | “Can you explain how CRISPR gene editing works?” |
# | **Practical life advice** | “What are effective strategies for managing a side‑project alongside a full‑time job?” |
# | **Creative writing** | “Can you help me brainstorm a plot twist for a sci‑fi short story?” |
#
# Feel free to pick any of those (or bring up something entirely different). I’ll respond directly and try to keep the answer as clear and useful as possible.
# ### Claude:
# Thank you for the thoughtful suggestions! I’d be delighted to dive into any topic that interests you. Which of the areas below would you like to explore first?
#
# - Artificial Intelligence
# - Programming & Software
# - Philosophy & Ethics
# - Science & Technology
# - Practical life advice
# - Creative writing
#
# Or feel free to bring up a completely different question—I’m ready whenever you are.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
